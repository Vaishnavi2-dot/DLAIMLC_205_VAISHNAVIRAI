# %%
import tensorflow as tf
import numpy as np

# %%
x = np.array([1, 2, 3, 4], dtype = float)
y = np.array([2, 4, 6, 8], dtype = float)

# %%
model = tf.keras.Sequential([
    tf.keras.Input(shape=(1,)),
    tf.keras.layers.Dense(1)
])

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
model.fit(x,y, epochs=10)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - loss: 3.5142
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 2.4406
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 1.6956
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 1.1787
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.8200
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.5711
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.3984
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.2786
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.1954
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.1377

# %%
#Use of keras

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
a = np.array([1, 2, 3, 4], dtype = float)
a = np.array([1, 2, 3, 4], dtype = float)

# %%
model = Sequential([
    Dense(1, input_shape = (1,))
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer = 'sgd', loss = 'mse')

# %%
model.fit(x, y, epochs=10)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - loss: 26.0941
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 18.1224
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 12.5909
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 8.7525
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 6.0891
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 4.2409
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 2.9584
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 2.0684
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 1.4508
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 1.0221

# %%
#PYTORCH

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
model = nn.Linear(1,1)

# %%
criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

# %%
x = torch.tensor([[1.],[2.],[3.],[4.]])
y = torch.tensor([[2.],[4.],[6.],[8.]])

# %%
for epoch in range(10):
  optimizer.zero_grad
  outputs = model(x)
  loss = criterion(outputs, y)
  loss.backward()
  optimizer.step()
  print(f"Epoch {epoch+1}, Loss: {loss.item()}")
# Out:
# Epoch 1, Loss: 47.415550231933594
# Epoch 2, Loss: 32.91320037841797
# Epoch 3, Loss: 13.191773414611816
# Epoch 4, Loss: 0.875308632850647
# Epoch 5, Loss: 3.8475184440612793
# Epoch 6, Loss: 20.205184936523438
# Epoch 7, Loss: 39.476470947265625
# Epoch 8, Loss: 49.324302673339844
# Epoch 9, Loss: 43.44376754760742
# Epoch 10, Loss: 25.59807586669922
